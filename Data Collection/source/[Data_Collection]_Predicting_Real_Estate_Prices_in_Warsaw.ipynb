# %% [markdown]
# #Data Collection for Predicting Real Estate Prices in Warsaw

# %% [markdown]
# ## Install and import libs

# %%
# !pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from bs4 import BeautifulSoup
import requests
import csv
import time
import pandas as pd
import re
from datetime import datetime
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## otodom.pl scrapper

# %% [markdown]
# ### Get data from otodom.pl

# %%
# Parameter specifying the maximum number of pages to be processed
max_pages = 100

# Parameter specifying the number of start page
start_page = 56

# URL for Warsaw
otodom_url = 'https://www.otodom.pl/pl/wyniki/sprzedaz/mieszkanie/mazowieckie/warszawa/warszawa/warszawa?page='

# HTTP headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# List to store records
records_otodom = []

def scrap_apartment_details(url):
    """
    This function scrapes detailed data from a specific apartment listing.

    - It sends an HTTP request to the provided URL to fetch the HTML content.
    - Parses the HTML using BeautifulSoup to extract various details.
    - Extracted details include price, price per square meter, number of rooms, area, location, description, update date, post date, and additional information.

    The function handles missing values by checking if elements exist before attempting to extract text.
    If an element is not found, it assigns 'N/A' as a placeholder.
    Returns a list of extracted details for further use.

    Args:
        url (str): The URL of the apartment listing.

    Returns:
        list: A list containing the extracted apartment details:
            - price
            - price per square meter
            - number of rooms
            - area
            - location
            - description
            - updated date
            - posted date
            - additional information 1
            - additional information 2
    """
    c = requests.get(url, headers=headers)
    soup_content = BeautifulSoup(c.content, 'html.parser')

    price = soup_content.find('strong', {'aria-label': 'Cena'}).text.strip() if soup_content.find('strong', {'aria-label': 'Cena'}) else 'N/A'
    price_per_m2 = soup_content.find('div', {'class': 'css-h8msn7 e1w5xgvx4'}).text.strip() if soup_content.find('div', {'class': 'css-h8msn7 e1w5xgvx4'}) else 'N/A'
    rooms = soup_content.find('div', {'aria-label': 'Liczba pokoi'}).text.strip() if soup_content.find('div', {'aria-label': 'Liczba pokoi'}) else 'N/A'
    area = soup_content.find('div', {'aria-label': 'Powierzchnia'}).text.strip() if soup_content.find('div', {'aria-label': 'Powierzchnia'}) else 'N/A'
    location = soup_content.find('a', {'class': 'css-1jjm9oe e42rcgs1'}).text.strip() if soup_content.find('a', {'class': 'css-1jjm9oe e42rcgs1'}) else 'N/A'
    description = soup_content.find('div', {'data-cy': 'adPageAdDescription'}).text.strip() if soup_content.find('div', {'data-cy': 'adPageAdDescription'}) else 'N/A'
    update_info = soup_content.find_all('p', {'class': 'e82kd4s2 css-htq2ld'})

    if len(update_info) >= 2:
        updated_date = update_info[0].text.strip()
        posted_date = update_info[1].text.strip()
    else:
        updated_date = posted_date = 'N/A'

    additional_info_1 = soup_content.find_all('div', {'class': 'css-1xbf5wd etn78ea0'})
    additional_info_1_text = ', '.join([info.text.strip() for info in additional_info_1]) if additional_info_1 else 'brak informacji'

    additional_info_2 = soup_content.find_all('div', {'class': 'etn78ea4 css-1nh5rfu'})
    additional_info_2_text = ', '.join([info.text.strip() for info in additional_info_2]) if additional_info_2 else 'brak informacji'

    return [price, price_per_m2, rooms, area, location, description, updated_date, posted_date, additional_info_1_text, additional_info_2_text]

def scrap_otodom(url):
    """
    Scrapes the Otodom listing page for apartment urls, then scrapes detailed information
    from each individual apartment listing.

    Args:
        url (str): The URL of the Otodom listing page.

    Returns:
        None: The function appends scraped data (source, link, title, and detailed info) to the global list `records_otodom`.
    """
    c = requests.get(url, headers=headers)
    soup_content = BeautifulSoup(c.content, 'html.parser')
    base_url = 'https://www.otodom.pl'

    # Search for all urls on page
    for listing in soup_content.find_all('a', {'data-cy': 'listing-item-link'}):
        relative_link = listing.get('href')
        full_link = base_url + relative_link

        title = listing.find('p', {'data-cy': 'listing-item-title'}).text.strip() if listing.find('p', {'data-cy': 'listing-item-title'}) else 'N/A'

        details = scrap_apartment_details(full_link)

        row = ["Otodom", full_link, title] + details
        records_otodom.append(row)
        print("Scraped:", full_link)

def save_to_csv(filename, records):
    """
    Saves the scraped records to a CSV file with specified column headers.

    Args:
        filename (str): The name of the CSV file where the data will be saved.
        records (list): A list of records, where each record is a list of scraped data.

    Returns:
        None: The function writes the data to the specified CSV file.
    """
    try:
        with open(filename, "w", newline='', encoding="utf-8") as f:
            writer = csv.writer(f)
            # Dodanie nagłówków CSV
            writer.writerow(['Source', 'Url', 'Title', 'Price', 'Pms', 'Rooms', 'Area', 'Location', 'Desc', 'Update date', 'Creation date' ,'Additional information 1', 'Additional information 2'])
            for record in records:
                writer.writerow(record)
        print(f'SaveToFile: {filename} OK.')
    except Exception as e:
        print(f'SaveToFile: ERROR. {e}')

def loop_for_scrap(base_url,start_page, max_pages):
    """
    Loops through the specified number of pages, sending a request to each page,
    and scrapes apartment listings using the scrap_otodom function.

    Args:
        base_url (str): The base URL of the listings with a page placeholder.
        max_pages (int): The maximum number of pages to scrape.
        start_page (int): The page number to start scraping from.

    Returns:
        None: Scrapes data from each page and appends the results to the global list.
    """
    for page_number in range(start_page, max_pages + 1):
        url = base_url + str(page_number)
        response = requests.head(url, headers=headers)
        if response.status_code < 400:
            scrap_otodom(url)
            time.sleep(2)
        else:
            break
        time.sleep(5)  # Delay between requests
        print(f"Page {page_number}")

# Start sraping
print("Starting scrap for Otodom...")
loop_for_scrap(otodom_url, start_page, max_pages)

# Global value for file name
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# Save data to .csv
save_to_csv(f'/content/drive/My Drive/Projects/Predicting Real Estate Prices in Warsaw/raw_otodom_{timestamp}.csv', records_otodom)
# Out:
# Starting scrap for Otodom...
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-obok-saska-kepa-super-widok-na-centrum-ID4rVur
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-42m2-balkon-bez-prowizji-ID4psCu
# Scraped: https://www.otodom.pl/pl/oferta/ochota-4-pok-76-66-m-garaz-ID4rUpF
# Scraped: https://www.otodom.pl/pl/oferta/narozne-3-sypialnie-duzy-balkon-przestronne-ID4rdMh
# Scraped: https://www.otodom.pl/pl/oferta/klimatyczne-2-pok-wsrod-zieleni-na-mokotowie-ID4saNZ
# Scraped: https://www.otodom.pl/pl/oferta/praga-poludnie-2-pokoje-1-pietro-paca-siennicka-ID4s2DR
# Scraped: https://www.otodom.pl/pl/oferta/oddzielna-kuchnia-garaz-komorka-lokatorska-ID4r1yg
# Scraped: https://www.otodom.pl/pl/oferta/przestronne-studio-z-mozliwoscia-podzialu-na-2-pok-ID4rp8P
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-w-kamienicy-z-winda-w-sercu-mokotowa-ID4rsTM
# Scraped: https://www.otodom.pl/pl/oferta/przestronne-studio-z-mozliwoscia-podzialu-na-2-pok-ID4rFJ5
# Scraped: https://www.otodom.pl/pl/oferta/nowoczesne-przestronne-balkon-22-mkw-ID4rR4m
# Scraped: https://www.otodom.pl/pl/oferta/kameralne-osiedle-przytulnosc-i-cisza-ID4rrlF
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowy-apartament-robyg-royal-residence-ID4rr3I
# Scraped: https://www.otodom.pl/pl/oferta/elegancki-apartament-262m-warszawa-wawer-anin-ID4suuq
# Scraped: https://www.otodom.pl/pl/oferta/bezposrednio-ul-iberyjska-4-po-remoncie-4-pok-ID4rgMt
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-z-ogrodkiem-w-nowej-inwestycji-bielany-ID4pSwd
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-z-ogrodkiem-w-nowej-inwestycji-bielany-ID4pSwf
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-z-ogrodkiem-w-nowej-inwestycji-bielany-ID4pSwc
# Scraped: https://www.otodom.pl/pl/oferta/45-41-m2-2-pok-metro-nowe-budownictwo-ID4pSwa
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-z-ogrodkiem-w-nowej-inwestycji-bielany-ID4pS5y
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-z-ogrodkiem-w-nowej-inwestycji-bielany-ID4pS5z
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-z-ogrodkiem-w-nowej-inwestycji-bielany-ID4pS5v
# Scraped: https://www.otodom.pl/pl/oferta/stara-ochota-klimatyczna-kamienica-2-pokoje-ID4pKuF
# Scraped: https://www.otodom.pl/pl/oferta/przestronna-kawalerka-przy-placu-konesera-ID4qGci
# Scraped: https://www.otodom.pl/pl/oferta/os-zamkniete-garaz-podziemny-winda-ID4snZ9
# Scraped: https://www.otodom.pl/pl/oferta/metro-natolin-3-pokoje-ursynow-balkon-kw-ID4smfs
# Scraped: https://www.otodom.pl/pl/oferta/kamienica-2-pokoje-galeria-mokotow-kw-balkon-ID4s0jl
# Scraped: https://www.otodom.pl/pl/oferta/super-po-remoncie-3-pok-kamienica-przy-metrze-ID4qZAL
# Scraped: https://www.otodom.pl/pl/oferta/fenomenalna-lokalizacja-2pok-przy-parku-dreszera-ID4r19L
# Scraped: https://www.otodom.pl/pl/oferta/znakomita-lokalizacja-79m2-4-pokoje-ul-rozlogi-ID4rSS5
# Scraped: https://www.otodom.pl/pl/oferta/super-lokalizacja-obok-parku-dreszera-3pok-66m2-ID4rUMi
# Scraped: https://www.otodom.pl/pl/oferta/bezposrednio-mieszkanie-50-m2-2-pokoje-na-bemowie-ID4suiv
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-39m2-ogrodek-bezposrednio-ID4mvm2
# Scraped: https://www.otodom.pl/pl/oferta/komorka-lokatorska-gratis-3-pokojowe-loggia-garaz-ID4rNx0
# Scraped: https://www.otodom.pl/pl/oferta/dobrze-skomunikowane-do-wlasnej-aranzacji-piwnica-ID4rAEK
# Scraped: https://www.otodom.pl/pl/oferta/do-wlasnej-aranzacji-piwnica-dobra-komunikacja-wum-ID4rQRN
# Scraped: https://www.otodom.pl/pl/oferta/zielona-okolica-nowe-instalacje-loggia-piwnica-ID4rmki
# Scraped: https://www.otodom.pl/pl/oferta/dwupokojowe-do-wprowadzenia-garaz-komorka-lok-ID4sj8H
# Scraped: https://www.otodom.pl/pl/oferta/przestronne-3-pokoje-balkon-piwnica-metro-ID4rVqW
# Page 56
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-35m-z-garazem-i-komorka-ID4swO8
# Scraped: https://www.otodom.pl/pl/oferta/penthouse-pod-klucz-4-pokoje-garaz-i-komorka-ID4qhef
# Scraped: https://www.otodom.pl/pl/oferta/3-pokoje-oddzielna-kuchnia-balkon-oddzielne-wc-ID4suZz
# Scraped: https://www.otodom.pl/pl/oferta/plac-hallera-nowa-praga-30m2-2-75m-wysokosci-ID4s2CN
# Scraped: https://www.otodom.pl/pl/oferta/wilcza-84-5m2-mozliwe-2-niezalezne-mieszkania-ID4slsS
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-47-m-ochota-szczesliwice-ID4saLx
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-37m2-2-pokoje-wwa-bielany-bezposrednio-ID4sutI
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-w-doskonalej-lokalizacji-dolny-mokotow-ID4s4Ql
# Scraped: https://www.otodom.pl/pl/oferta/ii-linia-zabudowy-spokojna-okolica-ID4slFj
# Scraped: https://www.otodom.pl/pl/oferta/bardzo-jasne-wysokosc-3-05-m-piekna-kamienica-ID4s1V9
# Scraped: https://www.otodom.pl/pl/oferta/widok-na-zielen-po-remoncie-instalacji-widne-ID4s8Vj
# Scraped: https://www.otodom.pl/pl/oferta/100m-od-metra-brodno-zielona-okolica-ID4sfKS
# Scraped: https://www.otodom.pl/pl/oferta/3-pokoje-rozkladowe-praga-poludnie-ul-opinogorska-ID4sn1k
# Scraped: https://www.otodom.pl/pl/oferta/zielen-przestronne-czerniakow-balkon-ID4rzJD
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-2pok-52-5m2-wykonczone-wysoki-standard-ID4rTCj
# Scraped: https://www.otodom.pl/pl/oferta/mokotow-rozkladowe-3-pok-z-widokiem-na-zielen-ID4sifx
# Scraped: https://www.otodom.pl/pl/oferta/3-pok-mieszkanie-tuz-przy-stacji-metra-trocka-ID4s2AD
# Scraped: https://www.otodom.pl/pl/oferta/nowoczesny-apartament-przy-arkadii-3-osobne-pokoje-ID4rK9P
# Scraped: https://www.otodom.pl/pl/oferta/triton-park-67m-2x-garaz-komorka-ID4sutx
# Scraped: https://www.otodom.pl/pl/oferta/gotowiec-inwestycyjny-nowoczesne-osiedle-arkadia-ID4qXO1
# Scraped: https://www.otodom.pl/pl/oferta/2-stronne-balkon-piwnica-6m-galeria-mokotow-5min-ID4s8sL
# Scraped: https://www.otodom.pl/pl/oferta/unikatowe-pod-airbnb-i-booking-zlote-tarasy-3min-ID4rQRQ
# Scraped: https://www.otodom.pl/pl/oferta/rondo-onz-balkon-piwnica-fabryka-norblina-3min-ID4rdMj
# Scraped: https://www.otodom.pl/pl/oferta/piekny-widok-klimatyzacja-balkon-galeria-mokotow-ID4rtOj
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-blisko-skm-i-przyszlej-stacji-metra-ID4sutu
# Scraped: https://www.otodom.pl/pl/oferta/sadyba-best-mall-2-poziomy-2-balkony-piwnica-garaz-ID4rioo
# Scraped: https://www.otodom.pl/pl/oferta/klimatyczne-dwupokojowe-mieszkanie-na-woli-ID4sc9p
# Scraped: https://www.otodom.pl/pl/oferta/trzypokojowe-mieszkanie-warszawa-wlochy-ID4sutc
# Scraped: https://www.otodom.pl/pl/oferta/kamienica-inwestycja-awf-uksw-dla-syna-corki-ID4s9ST
# Scraped: https://www.otodom.pl/pl/oferta/wykonczone-mieszkanie-na-nowym-osiedlu-ul-minska-ID4rx9W
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-w-dzielnicy-ursus-ID4rJeK
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-z-antresola-osiedle-wzgorze-slowikow-ID4sbIe
# Scraped: https://www.otodom.pl/pl/oferta/nowoczesny-apartament-w-doskonalej-lokalizacji-ID4s2Bq
# Scraped: https://www.otodom.pl/pl/oferta/atrakcyjny-3-pokojowy-apartament-na-zoliborzu-ID4s1Ef
# Scraped: https://www.otodom.pl/pl/oferta/apartament-133m2-5-pokoi-3-garaze-150m-do-metra-ID4rlfP
# Scraped: https://www.otodom.pl/pl/oferta/bezposrednio-centrum-grzybowska-warsaw-spire-ID4rkw5
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-przy-metro-plocka-winda-piwnica-ID4rWoF
# Scraped: https://www.otodom.pl/pl/oferta/okazja-duzy-balkon-ciche-klimatyzacja-ID4smFf
# Scraped: https://www.otodom.pl/pl/oferta/metro-natolin-9-min-jasne-ksiega-wieczysta-ID4rK2P
# Page 57
# Scraped: https://www.otodom.pl/pl/oferta/swietny-rozklad-cicha-okolica-bez-prowizji-ID4sgEP
# Scraped: https://www.otodom.pl/pl/oferta/mokotow-swietna-lokalizacja-3-pokoje-ID4rXAI
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-32m2-loggia-bez-prowizji-ID4rzVh
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-z-potencjalem-2-3-pokoje-ID4rtGT
# Scraped: https://www.otodom.pl/pl/oferta/3-pok-narozne-do-wprowadzenia-ursus-ID4rYI4
# Scraped: https://www.otodom.pl/pl/oferta/dwa-pokoje-do-wprowadzenia-blisko-skm-ursus-ID4rHgU
# Scraped: https://www.otodom.pl/pl/oferta/mieszkania-na-woli-w-swietnej-cenie-ID4sc5O
# Scraped: https://www.otodom.pl/pl/oferta/al-jerozolimskie-piekny-widok-po-remoncie-ID4q541
# Scraped: https://www.otodom.pl/pl/oferta/3-pok-do-remontu-dwustronne-blisko-parku-ID4rYI2
# Scraped: https://www.otodom.pl/pl/oferta/2-pok-do-wprowadzenia-ursus-ID4qIyb
# Scraped: https://www.otodom.pl/pl/oferta/dwa-pokoje-do-wprowadzenia-blisko-skm-ursus-ID4qAwg
# Scraped: https://www.otodom.pl/pl/oferta/mieszkania-na-woli-w-swietnej-cenie-bez-prowizji-ID4sc5P
# Scraped: https://www.otodom.pl/pl/oferta/3-pok-do-wprowadzenia-dwustronne-blisko-parku-ID4rN4o
# Scraped: https://www.otodom.pl/pl/oferta/trzy-pokoje-dwustronne-do-wprowadzenia-ursus-ID4s3ji
# Scraped: https://www.otodom.pl/pl/oferta/3-pok-dwustronne-kamienica-do-wprowadzenia-metro-ID4rYI6
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-z-duzym-balkonem-i-garderoba-bialoleka-ID4s30a
# Scraped: https://www.otodom.pl/pl/oferta/do-sprzedania-przestronne-mieszkanie-na-wlochach-ID4rYI5
# Scraped: https://www.otodom.pl/pl/oferta/nowe-4-pokoje-pod-klucz-garaz-i-komorka-bez-pcc-ID4qjG6
# Scraped: https://www.otodom.pl/pl/oferta/3pok-bez-pcc-bez-prowizji-oddane-do-uzytkowania-ID4sd1H
# Scraped: https://www.otodom.pl/pl/oferta/nowe-3-pokoje-pod-klucz-garaz-bez-pcc-ID4rF5z
# Scraped: https://www.otodom.pl/pl/oferta/2pok-bez-pcc-bez-prowizji-oddane-do-uzytkowania-ID4sd8P
# Scraped: https://www.otodom.pl/pl/oferta/nowy-penthouse-4-pokoje-pod-klucz-garaz-i-komorka-ID4s4JS
# Scraped: https://www.otodom.pl/pl/oferta/okazja-przestronne-mieszkanie-dla-rodziny-ID4sl5y
# Scraped: https://www.otodom.pl/pl/oferta/apartament-128m-taras-80m-widok-na-rezerwat-ID4qLjH
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-taras-130m2-garaz-mokotow-ID4qT7U
# Scraped: https://www.otodom.pl/pl/oferta/niska-zabudowapo-remonciemila-janapawla-ID4susx
# Scraped: https://www.otodom.pl/pl/oferta/przestronny-apartament-w-inwestycji-przy-arsenale-ID4rWlU
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-na-bielanach-blisko-metra-ID4rLyL
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-warszawa-srodmiescie-ID4sihE
# Scraped: https://www.otodom.pl/pl/oferta/luksusowy-apartament-w-unique-tower-ID4rZzR
# Scraped: https://www.otodom.pl/pl/oferta/unikatowy-apartament-w-samym-sercu-powisla-ID4rZHo
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-mieszkanie-63m2-2-balkony-ID4ly6Z
# Scraped: https://www.otodom.pl/pl/oferta/warszawa-srodmiescie-nowy-swiat-ID4josA
# Scraped: https://www.otodom.pl/pl/oferta/pachnace-nowoscia-2-pokoje-na-mokotowie-ID4sggf
# Scraped: https://www.otodom.pl/pl/oferta/82-m2-3-pokoje-2-miejsca-parkingowe-ursus-ID4sgB9
# Scraped: https://www.otodom.pl/pl/oferta/na-sprzedaz-wyjatkowy-jasny-dwupokojowy-apartament-ID4smfU
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-na-ul-gorczewskiej-blisko-metra-ID4rvl2
# Scraped: https://www.otodom.pl/pl/oferta/klimatyczne-mieszkanie-na-muranowie-ID4sed1
# Scraped: https://www.otodom.pl/pl/oferta/3-pokoje-do-remontu-60m2-metro-ursynow-ID4sogY
# Page 58
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-46m2-ogrodek-ID4pn9Z
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-mieszkanie-60m2-odbior-w-2024-wlochy-ID4ssTz
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-mieszkanie-58m2-balkon-ID4ojrM
# Scraped: https://www.otodom.pl/pl/oferta/okazja-idealna-oferta-na-inwestycje-ID4sizO
# Scraped: https://www.otodom.pl/pl/oferta/111-mkw-tarasu-na-dachu-do-wylacznego-korzystania-ID4feXK
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-na-grochowie-3-pokoje-kuchnia-ID4oOsV
# Scraped: https://www.otodom.pl/pl/oferta/2-pok-falata-rakowiecka-metro-pole-mokotowskie-ID4surR
# Scraped: https://www.otodom.pl/pl/oferta/bez-prowizji-ochota-kamienica-kw-mochnackiego-ID4saEU
# Scraped: https://www.otodom.pl/pl/oferta/bezposrednio-park-morskie-oko-zabytkowa-kamienica-ID4peMn
# Scraped: https://www.otodom.pl/pl/oferta/4-pokojowe-mieszkanie-95m2-balkon-ID4q2oQ
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-z-pieknym-widokiem-ID4surr
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-na-zaciszu-idealne-dla-rodziny-singli-ID4sswY
# Scraped: https://www.otodom.pl/pl/oferta/apartament-3-pok-2-loggie-mokotow-metro-ID4s8VN
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-na-warszawskim-powislu-lipowa-9-56m-ID4suru
# Scraped: https://www.otodom.pl/pl/oferta/przytulna-kawalerka-wola-jana-kazimierza-ID4surC
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-mieszkanie-ID4pMZu
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-3-30wys-ogrodek-45m-garaz-komorka-ID4rnnq
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-na-mokotowie-z-ogrodem-ID4surq
# Scraped: https://www.otodom.pl/pl/oferta/ladne-dwupokojowe-urzadzone-przy-parku-ID4ssCQ
# Scraped: https://www.otodom.pl/pl/oferta/super-lokalizacja-na-rakowcu-skm-park-ID4qeEA
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-mieszkanie-bezposrednio-ul-ceramiczna-ID4surl
# Scraped: https://www.otodom.pl/pl/oferta/4-pok-metro-plocka-balkon-do-aranzacji-ID4se1K
# Scraped: https://www.otodom.pl/pl/oferta/piekny-duzy-sloneczny-i-cichy-obok-centrum-ID4s7zP
# Scraped: https://www.otodom.pl/pl/oferta/studio-al-ujazdowskie-8-warszawa-ID4shzx
# Scraped: https://www.otodom.pl/pl/oferta/4-pokojowe-mieszkanie-w-miasteczku-wilanow-ID4surg
# Scraped: https://www.otodom.pl/pl/oferta/funkcjonalna-kawalerka-w-zielonej-okolicy-ID4qXMk
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-warszawa-ul-seceminska-ID4saBa
# Scraped: https://www.otodom.pl/pl/oferta/do-sprzedania-2-pokojowe-mieszkanie-46m2-na-sluzew-ID4sjmI
# Scraped: https://www.otodom.pl/pl/oferta/metro-mlociny-sokratesa-48m2-2-ogrodki-ID4sgbc
# Scraped: https://www.otodom.pl/pl/oferta/taras-fantastyczny-duzy-piekny-2-pokojowe-garaz-ID4qtEB
# Scraped: https://www.otodom.pl/pl/oferta/komorka-lokatorska-gratis-blisko-lotniska-3-pokoj-ID4qYoD
# Scraped: https://www.otodom.pl/pl/oferta/komorka-lok-gratis-69m2-przy-metrze-duzy-balkon-ID4rE8Y
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-ul-sokratesa-13c-metro-mlociny-ID4rJTB
# Scraped: https://www.otodom.pl/pl/oferta/chmielna-duo-mieszkanie-1-pok-b1-3-ID4rG2V
# Scraped: https://www.otodom.pl/pl/oferta/kw-bezposrednio-nowe-klima-ostatnie-pietro-ID4sgc9
# Scraped: https://www.otodom.pl/pl/oferta/ogrodek-140m2-tylko-12-km-do-centrum-wwy-design-ID4s9KP
# Scraped: https://www.otodom.pl/pl/oferta/bardzo-widny-duzy-apartament-taras-park-cietrzewia-ID4qXrs
# Page 59
# Scraped: https://www.otodom.pl/pl/oferta/przytulne-m2-na-zielonym-spokojnym-osiedlu-ID4suU0
# Scraped: https://www.otodom.pl/pl/oferta/metro-ursynow-balkon-winda-osobna-kuchnia-okno-ID4swTd
# Scraped: https://www.otodom.pl/pl/oferta/nowosc-przy-galerii-polnocnej-tarchomin-m3-ID4q68t
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-84-m-warszawa-ID4pZRw
# Scraped: https://www.otodom.pl/pl/oferta/3-pokoje-w-stanie-deweloperskim-skanska-nu-wola-ID4qNZg
# Scraped: https://www.otodom.pl/pl/oferta/3-pokoje-wola-wysoki-standard-ID4smW1
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-oddzielna-kuchnia-ID4suqQ
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-inwestycja-solen-kabaty-ID4mjG7
# Scraped: https://www.otodom.pl/pl/oferta/miasteczko-jutrzenki-mieszkanie-106e-m074-ID4ria4
# Scraped: https://www.otodom.pl/pl/oferta/dwupokojowe-mieszkanie-przy-metrze-sluzew-ID4si64
# Scraped: https://www.otodom.pl/pl/oferta/piekny-dom-na-bliskich-bielanach-ID4r9Yu
# Scraped: https://www.otodom.pl/pl/oferta/11-pietro-jasne-wysokie-soho-factory-ID4qL6d
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-z-pieknym-widokiem-na-park-brodnowski-ID4soR6
# Scraped: https://www.otodom.pl/pl/oferta/kw-bezposrednio-nowe-klima-duza-garderoba-ID4sgbY
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-ciche-mieszkanie-w-kamienicy-z-1926-r-ID4suqE
# Scraped: https://www.otodom.pl/pl/oferta/w-pelni-wyposazone-komfortowe-wola-libre-ID4rhmA
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-2-pokoje-w-kamienicy-na-woli-ID4robc
# Scraped: https://www.otodom.pl/pl/oferta/ciche-mieszkanie-w-stylu-glamour-wilanow-ID4suqM
# Scraped: https://www.otodom.pl/pl/oferta/imielin-3-pokoje-10min-do-metra-stoklosy-0-prowizj-ID4sh3S
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-klimatyczna-kamienica-przy-laziankach-ID4rAMT
# Scraped: https://www.otodom.pl/pl/oferta/piekne-3-pokojowe-mieszkanie-ID4s59A
# Scraped: https://www.otodom.pl/pl/oferta/super-2-pokoje-na-mokotowie-ID4rfUr
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-w-inwestycji-ostoja-wilanow-ID4rBif
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-inwestycyjne-na-rynku-nowego-miasta-ID4rGFI
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-w-sasiedztwie-parku-muranow-ID4rDRv
# Scraped: https://www.otodom.pl/pl/oferta/przestronne-mieszkanie-na-ursynowie-dwa-tarasy-ID4sgCj
# Scraped: https://www.otodom.pl/pl/oferta/doswietlone-przestrzenne-2-pokoje-dolny-mokotow-ID4rCi9
# Scraped: https://www.otodom.pl/pl/oferta/funkcjonalne-3-pokoje-na-ostatnim-pietrze-ID4s4ts
# Scraped: https://www.otodom.pl/pl/oferta/kameralny-penthouse-ze-127-metrowym-tarasem-ID4s0ab
# Scraped: https://www.otodom.pl/pl/oferta/kawalerka-z-duzym-ogrodkiem-sady-zoliborzskie-ID4s4x6
# Scraped: https://www.otodom.pl/pl/oferta/4-pokojowe-mieszkanie-94m2-balkon-bezposrednio-ID4ly86
# Scraped: https://www.otodom.pl/pl/oferta/swietne-dwupokojowe-mieszkanie-praga-polnoc-ID4rC7z
# Scraped: https://www.otodom.pl/pl/oferta/piekne-mieszkanie-w-zrewitalizowanej-kamienicy-ID4s4zs
# Scraped: https://www.otodom.pl/pl/oferta/odswiezone-trzypokojowe-mieszkanie-na-woli-ID4rzQb
# Scraped: https://www.otodom.pl/pl/oferta/dwupokojowe-mieszkanie-blisko-metra-pkp-parking-ID4rZEF
# Scraped: https://www.otodom.pl/pl/oferta/dwupokojowe-mieszkanie-dwa-balkony-ID4s26X
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-mieszkanie-warszawa-wola-piwnica-ID4s26x
# Scraped: https://www.otodom.pl/pl/oferta/ustawne-4-pokoje-na-ii-pietrze-balkon-poematu-ID4rTb7
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-3-pokoje-ogrodek-taras-bialoleka-ID4s4zt
# Page 60
# Scraped: https://www.otodom.pl/pl/oferta/swietny-rozklad-cicha-okolica-bez-prowizji-ID4sgEP
# Scraped: https://www.otodom.pl/pl/oferta/bezposrdnio-50m2-praga-polnoc-ID4suYz
# Scraped: https://www.otodom.pl/pl/oferta/warszawa-mokotow-ul-raclawicka-46-ID4rUx5
# Scraped: https://www.otodom.pl/pl/oferta/piekne-mieszkanie-w-przedwojennej-kamienicy-ID4s52J
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-50m2-loggia-bezposrednio-ID4kHIc
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-mieszkanie-57m2-2-loggie-bezposrednio-ID4qfNJ
# Scraped: https://www.otodom.pl/pl/oferta/4-pokojowe-mieszkanie-80m2-taras-bezposrednio-ID4l3g9
# Scraped: https://www.otodom.pl/pl/oferta/atrakcyjne-i-wyjatkowe-107mkw-na-ursynowie-ID4soh9
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-40m2-loggia-bezposrednio-ID4rvQl
# Scraped: https://www.otodom.pl/pl/oferta/4-pokojowe-mieszkanie-76m2-balkon-ID4pVhA
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-42m2-balkon-bezposrednio-ID4q9jx
# Scraped: https://www.otodom.pl/pl/oferta/stary-zoliborz-ul-hanki-czaki-2-pokoje-36-5-m2-ID4s6pn
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-33m2-balkon-bezposrednio-ID4ojrG
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-mieszkanie-74m2-ogrodek-bezposrednio-ID4qtEr
# Scraped: https://www.otodom.pl/pl/oferta/4-pokojowe-mieszkanie-76m2-2-balkony-ID4rruR
# Scraped: https://www.otodom.pl/pl/oferta/4-pokojowe-mieszkanie-87m2-balkon-ID4ot9E
# Scraped: https://www.otodom.pl/pl/oferta/m5-110m-3-sypialnie-2-lazienki-2-tarasy-garaz-ID4sdrd
# Scraped: https://www.otodom.pl/pl/oferta/kawalerka-w-spokojnej-okolicy-ul-obozowa-wola-ID4sb0W
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-z-widokiem-na-jeziorko-ID4sdNv
# Scraped: https://www.otodom.pl/pl/oferta/3-pokoje-z-ogrodem-parking-miasteczko-wilanow-ID4sdsC
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-w-swietnej-lokalizacji-zoliborz-ID4rRCQ
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-z-garderoba-do-wejscia-na-sielcach-ID4rRjW
# Scraped: https://www.otodom.pl/pl/oferta/spokoj-w-centrum-miasta-warszawa-wola-m2-ID4rQvT
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-w-nowym-budownictwie-ID4rQvS
# Scraped: https://www.otodom.pl/pl/oferta/dwupoziomowy-apartament-do-wlasnej-aranzacji-ID4qalN
# Scraped: https://www.otodom.pl/pl/oferta/apartament-z-widokiem-na-tor-wyscigow-konnych-ID4seni
# Page 61
# Scraped: https://www.otodom.pl/pl/oferta/unikatowe-2-pokojowe-mieszkanie-wys-3-80-m-ID4qUDl
# Scraped: https://www.otodom.pl/pl/oferta/swiezo-wyremontowana-kawalerka-przy-mokotowskiej-ID4swdv
# Scraped: https://www.otodom.pl/pl/oferta/dwustronne-m3-50-m-kw-przy-bazylice-ul-siedlecka-ID4rBKA
# Scraped: https://www.otodom.pl/pl/oferta/targowa-70-kamienica-65m2-15m2-piwnica-ID4siPs
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-ciche-mieszkanie-na-nowolipkach-ID4siYJ
# Scraped: https://www.otodom.pl/pl/oferta/czteropokojowe-mieszkanie-na-sprzedaz-nowe-miasto-ID4so52
# Scraped: https://www.otodom.pl/pl/oferta/3-pokoje-komorka-w-cenie-garaz-ID4rVPC
# Scraped: https://www.otodom.pl/pl/oferta/penthouse-na-mokotowie-z-widokiem-na-city-ID4snth
# Scraped: https://www.otodom.pl/pl/oferta/trzypokojowe-mieszkanie-na-sprzedaz-wilanow-ID4sokW
# Scraped: https://www.otodom.pl/pl/oferta/dwupokojowe-mieszkanie-z-osobna-kuchnia-ochota-ID4sjxO
# Scraped: https://www.otodom.pl/pl/oferta/4-pokoje-przy-parku-szczesliwickim-ID4sqfU
# Scraped: https://www.otodom.pl/pl/oferta/wyjatkowe-4-pokoje-kamienica-srodmiescie-ID4rLeE
# Scraped: https://www.otodom.pl/pl/oferta/jasne-dwustronne-3-pokojowe-targowek-ID4sczt
# Scraped: https://www.otodom.pl/pl/oferta/jasne-rozkladowe-2-stronne-sady-zoliborskie-ID4s8Rt
# Scraped: https://www.otodom.pl/pl/oferta/okazja-jasne-duza-loggia-stara-ochota-ID4sslG
# Scraped: https://www.otodom.pl/pl/oferta/dwustronne-mieszkanie-na-ostatnim-pietrze-na-woli-ID4srpl
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-w-budynku-apartamentowym-wola-libre-ID4srDf
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-41m2-balkon-bezposrednio-ID4ly7b
# Scraped: https://www.otodom.pl/pl/oferta/56-m-przy-metrze-wilanowska-ID4ssPt
# Scraped: https://www.otodom.pl/pl/oferta/lazurowa-nowe-mieszkanie-metro-zachod-ID4rMmq
# Scraped: https://www.otodom.pl/pl/oferta/urbino-nowe-mieszkanie-z-balkonem-ID4rMmm
# Scraped: https://www.otodom.pl/pl/oferta/bialej-koniczyny-mieszkanie-z-ogrodkiem-2024r-ID4rMmk
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-41-m-warszawa-ID4rqE6
# Scraped: https://www.otodom.pl/pl/oferta/luksusowy-apartament-na-marinie-mokotow-ID4ssX5
# Scraped: https://www.otodom.pl/pl/oferta/wilanow-2-pokoje-47m2-do-wprowadzenia-ID4sfJn
# Scraped: https://www.otodom.pl/pl/oferta/gagarina-33-perelka-obok-lazienek-krolewskich-ID4s9Kv
# Scraped: https://www.otodom.pl/pl/oferta/praga-polnoc-4-pok-95-39-m-pietro-4-ID4qHQh
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-przestronne-jasne-mieszkanie-78-m2-ID4sn6q
# Scraped: https://www.otodom.pl/pl/oferta/scisle-centrum-przestronne-2-pokojowe-mieszkanie-ID4sgaC
# Scraped: https://www.otodom.pl/pl/oferta/okazja-54-6-m2-z-ogrodkiem-wilanow-zawady-ID4stNk
# Scraped: https://www.otodom.pl/pl/oferta/cegla-piwnica-sielce-ID4sgaA
# Scraped: https://www.otodom.pl/pl/oferta/fabrica-ursus-mieszkanie-2-pok-a1-2-070-ID4ri04
# Scraped: https://www.otodom.pl/pl/oferta/klimatyczne-2-pokojowe-pow-46-35m2-ochota-ID4p7qj
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-z-antresola-po-remoncie-ID4o886
# Scraped: https://www.otodom.pl/pl/oferta/narozne-gotowe-do-wprowadzenia-sie-4-pokoje-ID4rg6u
# Scraped: https://www.otodom.pl/pl/oferta/przy-parku-ID4rWON
# Scraped: https://www.otodom.pl/pl/oferta/2-pok-widok-na-wwe-15-min-do-m1-bezposrednio-ID4rTos
# Scraped: https://www.otodom.pl/pl/oferta/kawalerka-z-balkonem-blisko-wum-ID4skIK
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-2-pokojowe-z-balkonem-warszawa-ochota-ID4sqqw
# Page 62
# Scraped: https://www.otodom.pl/pl/oferta/1-pokojowe-mieszkanie-29m2-balkon-ID4rl6y
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-36m2-balkon-ID4qtrP
# Scraped: https://www.otodom.pl/pl/oferta/dwustronne-m3-50-m-kw-przy-bazylice-ul-siedlecka-ID4rBKA
# Scraped: https://www.otodom.pl/pl/oferta/2-pok-widok-na-wwe-15-min-do-m1-bezposrednio-ID4rTos
# Scraped: https://www.otodom.pl/pl/oferta/kawalerka-z-balkonem-blisko-wum-ID4skIK
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-2-pokojowe-z-balkonem-warszawa-ochota-ID4sqqw
# Scraped: https://www.otodom.pl/pl/oferta/metro-bemowo-blisko-wat-garaz-34-8m2-ID4s3Tv
# Scraped: https://www.otodom.pl/pl/oferta/dwustronne-mieszkanie-2pokoje-osobna-kuchnia-45m2-ID4srbO
# Scraped: https://www.otodom.pl/pl/oferta/widok-na-palac-kultury-2-str-do-wprowadzenia-ID4oEmi
# Scraped: https://www.otodom.pl/pl/oferta/widok-na-palac-kultury-2-str-do-wprowadzenia-ID4p1ol
# Scraped: https://www.otodom.pl/pl/oferta/2-duze-pokoje-zielone-osiedle-bemowo-49-91m2-ID4qzoR
# Scraped: https://www.otodom.pl/pl/oferta/zoliborz-kawalerka-teatr-komedia-metro-ID4shq8
# Scraped: https://www.otodom.pl/pl/oferta/dwupokojowe-mieszkanie-wilanow-ID4suq3
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-51-66-m-warszawa-ID4niMP
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-47-74-m-warszawa-ID4o24r
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-40-m-warszawa-ID4q5vH
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-29-81-m-warszawa-ID4q5vK
# Scraped: https://www.otodom.pl/pl/oferta/dwulokalowe-mieszkanie-na-mokotowie-nowa-cena-ID4qEWN
# Scraped: https://www.otodom.pl/pl/oferta/4-pokoje-garaz-metro-sluzew-150m-po-remoncie-ID4rILA
# Scraped: https://www.otodom.pl/pl/oferta/wilanow-apartament-180m2-z-duzym-ogrodem-ID4sn18
# Scraped: https://www.otodom.pl/pl/oferta/wygodny-apartament-w-sercu-woli-ID4s9FF
# Scraped: https://www.otodom.pl/pl/oferta/nowoczesny-kameralny-apartamentowiec-na-bielanach-ID4rl4p
# Scraped: https://www.otodom.pl/pl/oferta/elegancki-apartament-z-4-sypialniami-ID4rbgc
# Scraped: https://www.otodom.pl/pl/oferta/kawalerka-zoliborz-bezposrednio-ID4skTx
# Scraped: https://www.otodom.pl/pl/oferta/kawalerka-ul-braci-wagow-11-ID4rMsX
# Scraped: https://www.otodom.pl/pl/oferta/0-od-kupujacego-ID4saLU
# Scraped: https://www.otodom.pl/pl/oferta/taras-po-remoncie-generalnym-idealne-pod-wynajem-ID4sbEu
# Scraped: https://www.otodom.pl/pl/oferta/wysokie-z-balkonem-w-kamienicy-1912-z-winda-ID4sqRD
# Scraped: https://www.otodom.pl/pl/oferta/swiezo-po-remoncie-w-kamienicy-z-1934-ID4rpbJ
# Scraped: https://www.otodom.pl/pl/oferta/piekne-po-remoncie-w-kamienicy-przy-ul-pieknej-ID4rpbI
# Scraped: https://www.otodom.pl/pl/oferta/3-pok-do-wprowadzenia-blisko-metra-bemowo-ID4supP
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-mieszkanie-63m2-2-balkony-ID4ly89
# Scraped: https://www.otodom.pl/pl/oferta/okazja-dwupoziomowe-mieszkanie-w-kamienicy-ID4paZf
# Scraped: https://www.otodom.pl/pl/oferta/sloneczne-mieszkanie-z-duzym-tarasem-na-goclawiu-ID4srgT
# Scraped: https://www.otodom.pl/pl/oferta/do-wprowadzenia-z-duzym-balonem-dwustronne-ID4sjh1
# Scraped: https://www.otodom.pl/pl/oferta/bemowo-ul-czumy-50m2-2pok-balkon-metro-ID4spb4
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-lm7-jasna-wschodnia-strona-ID4o9pe
# Scraped: https://www.otodom.pl/pl/oferta/apartamenty-talarowa-3-11-ID4rVkj
# Scraped: https://www.otodom.pl/pl/oferta/nova-kuligowska-budynek-2-mieszkanie-p2-77m2-ID4ojzz
# Page 63
# Scraped: https://www.otodom.pl/pl/oferta/1-pokojowe-mieszkanie-43m2-ogrodek-ID4rHOI
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-o-wysokim-standardzie-w-malym-blok-ID4rcEF
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-49m2-loggia-ID4pn9K
# Scraped: https://www.otodom.pl/pl/oferta/nova-kuligowska-budynek-2-mieszkanie-p2-77m2-ID4ojzz
# Scraped: https://www.otodom.pl/pl/oferta/stylowa-inwestycja-w-sercu-brzezin-10min-do-metra-ID4oaU1
# Scraped: https://www.otodom.pl/pl/oferta/najlepsza-cena-komorka-lokatorska-gratis-ID4kfML
# Scraped: https://www.otodom.pl/pl/oferta/vonder-uptown-apartament-1-pok-8-ID4sews
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-mieszkanie-58-m2-2-pietro-bezposrednio-ID4seXA
# Scraped: https://www.otodom.pl/pl/oferta/ladne-mieszkanie-z-ogrodkami-w-okolicy-parku-ID4smYF
# Scraped: https://www.otodom.pl/pl/oferta/praga-polnoc-ul-szwedzka-wysokie-4-m-ID4rECH
# Scraped: https://www.otodom.pl/pl/oferta/bezposrednio-przy-parku-zniczadyskretny-parter-ID4smXJ
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-47-mkw-brodno-metro-park-szkola-ID4smQA
# Scraped: https://www.otodom.pl/pl/oferta/m3-blisko-centrum-przy-wkd-i-korcie-tenisowym-ID4skQL
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-w-miasteczku-wilanow-garaz-komorka-ID4skPU
# Scraped: https://www.otodom.pl/pl/oferta/muranow-1-pok-20m2-inwestycyjne-bookingowe-ID4qbVe
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-mieszkanie-54m2-loggia-bez-prowizji-ID4mvlO
# Scraped: https://www.otodom.pl/pl/oferta/kawalerka-28m2-na-muranowie-ID4rTkG
# Scraped: https://www.otodom.pl/pl/oferta/unikatowe-mieszkanie-przy-koneserze-i-metrze-ID4suoV
# Scraped: https://www.otodom.pl/pl/oferta/bezposrednio-ciche-duzy-balkon-na-zielone-patio-ID4suoO
# Scraped: https://www.otodom.pl/pl/oferta/zoliborz-mieszkanie-ok-300-m2-dzialki-0-prowizji-ID4rxbS
# Scraped: https://www.otodom.pl/pl/oferta/50m2-metro-ksiecia-janusza-park-moczydlo-ID4s9GK
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-z-widna-kuchnia-15-min-od-centrum-ID4suoH
# Scraped: https://www.otodom.pl/pl/oferta/apartament-2-pokojowy-z-widna-kuchnia-taras-24m2-ID4suoB
# Scraped: https://www.otodom.pl/pl/oferta/5-pokoi-50m-tarasu-30m-loggia-wola-14-pietro-ID4s6Is
# Scraped: https://www.otodom.pl/pl/oferta/przestronny-apartament-3-pokojowy-z-dwoma-tarasami-ID4suoz
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-w-apartamentowcu-w-15-min-do-centrum-ID4suoy
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-mieszkanie-74-40-m2-ursus-skorosze-ID4s2ro
# Scraped: https://www.otodom.pl/pl/oferta/mokotow-piekne-2-pokoje-do-wprowadzenia-balkon-ID4sm9F
# Scraped: https://www.otodom.pl/pl/oferta/zamieszkaj-w-slonecznym-mieszkaniu-wsrod-zieleni-ID4sac4
# Scraped: https://www.otodom.pl/pl/oferta/wawer-zwolen-69m2-ID4sarC
# Scraped: https://www.otodom.pl/pl/oferta/apartament-78m2-z-widokiem-na-zielen-3-pok-ID4sunU
# Scraped: https://www.otodom.pl/pl/oferta/widok-na-park-zeromskiego-garaz-winda-ID4sqs7
# Scraped: https://www.otodom.pl/pl/oferta/mokotow-padewska-41m2-2-p-po-remoncie-kamienica-ID4sc1i
# Scraped: https://www.otodom.pl/pl/oferta/3-pokoje-2-minuty-od-metra-slodowiec-ID4qrLp
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-bezposrednio-warszawa-saska-kepa-ID4saq9
# Scraped: https://www.otodom.pl/pl/oferta/zoliborz-2-pok-i-pietro-balkon-ID4snDv
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-2-pok-47-m2-al-rzeczypospolitej-22b-ID4rTfG
# Scraped: https://www.otodom.pl/pl/oferta/piekny-3-pokojowy-apartament-na-ursynowie-ID4sunf
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-mieszkanie-60m2-praga-poludnie-ID4sun1
# Page 64
# Scraped: https://www.otodom.pl/pl/oferta/przestronne-mieszkanie-al-jana-pawla-ii-61-ID4qLHv
# Scraped: https://www.otodom.pl/pl/oferta/klimatyczne-odnowione-2-pokoje-i-osobna-kuchnia-ID4sw1D
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-46m2-ogrodek-bezposrednio-ID4rzFU
# Scraped: https://www.otodom.pl/pl/oferta/nowa-kawalerka-ul-domaniewska-wysoki-standard-ID4rTf9
# Scraped: https://www.otodom.pl/pl/oferta/100m-od-ronda-wiatraczna-dwa-balkony-2006r-ID4sumR
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-ID4qt1G
# Scraped: https://www.otodom.pl/pl/oferta/bezposrednio-94-m2-tarchomin-3-sypialnie-salon-ID4sumK
# Scraped: https://www.otodom.pl/pl/oferta/obywatelska-2-pok-widne-bezposrednio-ID4nKnr
# Scraped: https://www.otodom.pl/pl/oferta/wilanow-goplanska-mieszkanie-2-pokojowe-ID4sanP
# Scraped: https://www.otodom.pl/pl/oferta/rozkladowe-w-swietnej-lokalizacji-na-bemowie-ID4sumC
# Scraped: https://www.otodom.pl/pl/oferta/bemowo-kameralne-osiedle-super-miejsce-ID4sumu
# Scraped: https://www.otodom.pl/pl/oferta/wysoki-standard-mozliwe-4-pokoje-zielona-okolica-ID4suml
# Scraped: https://www.otodom.pl/pl/oferta/przytulne-3-pokojowe-mieszkanie-z-duzym-ogrodkiem-ID4rfou
# Scraped: https://www.otodom.pl/pl/oferta/wawer-99m2-ID4saoI
# Scraped: https://www.otodom.pl/pl/oferta/bezposrednio-m4-metro-lazarski-po-remoncie-ID4rTdw
# Scraped: https://www.otodom.pl/pl/oferta/3-oddzielne-pokoje-blisko-metra-sluzew-ID4s1HZ
# Scraped: https://www.otodom.pl/pl/oferta/studio-z-aneksem-sypialnianym-odebrane-jest-kw-ID4sbbz
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-3-pokojowe-wola-szulborska-1200-m-metro-ID4samA
# Scraped: https://www.otodom.pl/pl/oferta/wyjatkowe-mieszkanie-z-duzym-ogrodkiem-i-tarasem-ID4sum1
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-50-90-m-warszawa-ID4sulP
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-2-pokojowe-z-pieknym-widokiem-metro-ID4spZQ
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-mieszkanie-na-warszawskim-goclawiu-ID4rTca
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-garaz-podziemny-warszawa-praga-poludnie-ID4rxbI
# Scraped: https://www.otodom.pl/pl/oferta/nowoczesne-przy-metrze-kondratowicza-targowek-ID4slZw
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-w-centrum-warszawy-na-sprzedaz-ID4rKx9
# Scraped: https://www.otodom.pl/pl/oferta/blisko-lazienek-wykonczone-pod-klucz-wyjatkowe-ID4suli
# Scraped: https://www.otodom.pl/pl/oferta/apartament-300-metrow-od-lasu-kabackiego-ID4san6
# Scraped: https://www.otodom.pl/pl/oferta/blisko-metra-cisza-i-duzo-zieleni-ul-puszczyka-ID4samT
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-49m2-ogrodek-ID4q9jy
# Scraped: https://www.otodom.pl/pl/oferta/bezposrednio-2-pokojowe-mieszkanie-48m-praga-polud-ID4rTab
# Scraped: https://www.otodom.pl/pl/oferta/bezposrednio-kawalerka-metro-sluzew-blacharska-ID4samz
# Scraped: https://www.otodom.pl/pl/oferta/80-metrow-od-metra-mlociny-bezposrednio-63-2m-ID4sukZ
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-28-m-warszawa-ID4sukW
# Scraped: https://www.otodom.pl/pl/oferta/okazja-lazienki-nowoczesne-mieszkanie-2-balkony-ID4sami
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-bezposrednio-mieszkanie-warszawa-goclaw-ID4rT9r
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-2-pokojowe-garaz-komorka-lokatorska-ID4suky
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-3-pokoje-warszawa-praga-polnoc-ID4sukq
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-61-50-m-warszawa-ID4sukp
# Page 65
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-mieszkanie-62m2-balkon-bez-prowizji-ID4idcb
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-bezposrednio-47-49m2-2-pok-1-pietro-ID4swPu
# Scraped: https://www.otodom.pl/pl/oferta/kawalerka-na-nowolipkach-ID4rWIn
# Scraped: https://www.otodom.pl/pl/oferta/lokalizacja-eleganckie-funkcjonalne-parking-ID4rKwg
# Scraped: https://www.otodom.pl/pl/oferta/3-pokojowe-mieszkanie-53m2-balkon-bez-prowizji-ID4rkFG
# Scraped: https://www.otodom.pl/pl/oferta/stylowe-mieszkanie-z-tarasem-galeria-mokotow-ID4suk3
# Scraped: https://www.otodom.pl/pl/oferta/wygodne-zamieszkanie-i-swietna-inwestycja-ID4qity
# Scraped: https://www.otodom.pl/pl/oferta/bracka-okolice-ul-nowy-swiat-ID4sq18
# Scraped: https://www.otodom.pl/pl/oferta/narozne-widne-przestronne-z-widokiem-na-zielen-ID4sujO
# Scraped: https://www.otodom.pl/pl/oferta/dwupokojowe-mieszkanie-na-mokotowie-ID4rOxz
# Scraped: https://www.otodom.pl/pl/oferta/trzy-wygodne-pokoje-z-oddzielna-kuchnia-ID4sujr
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-30m-od-metra-stoklosy-ursynow-53m2-ID4s0Ky
# Scraped: https://www.otodom.pl/pl/oferta/bez-prowizji-3-pokoje-bez-pcc-wykonczone-ID4rJPI
# Scraped: https://www.otodom.pl/pl/oferta/bez-prowizji-3-pokoje-bez-pcc-komorka-las-ID4rJQo
# Scraped: https://www.otodom.pl/pl/oferta/wyjatkowe-ciche-mieszkanie-na-osiedlu-19dzielnica-ID4sq0T
# Scraped: https://www.otodom.pl/pl/oferta/ostatnie-m-4-z-tarasem-46m2-odbior-w-tym-roku-ID4suj2
# Scraped: https://www.otodom.pl/pl/oferta/po-remoncie-cicha-i-zielona-okolica-bez-prowizji-ID4suj0
# Scraped: https://www.otodom.pl/pl/oferta/bezposrednio-4-pokoje-bielany-rudnickiego-3a-ID4suiY
# Scraped: https://www.otodom.pl/pl/oferta/ochota-2-pokoje-super-widok-w-standard-ID4sh49
# Scraped: https://www.otodom.pl/pl/oferta/3pok-56m2-ogrodek-taras-17m2-garaz-w-wesolej-ID4suiW
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-apartament-na-sadach-zoliborskich-ID4mOp2
# Scraped: https://www.otodom.pl/pl/oferta/penthouse-92-m2-z-tarasem-38m2-mokotow-metro-ID4suiP
# Scraped: https://www.otodom.pl/pl/oferta/jasne-2-pokoje-z-klima-od-zaraz-ID4s55I
# Scraped: https://www.otodom.pl/pl/oferta/przestronne-2-pokojowe-mieszkanie-bemowo-wola-ID4rT5y
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-dobra-komunikacja-muranow-ID4sak8
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-bielany-metro-mlociny-ID4qVF0
# Scraped: https://www.otodom.pl/pl/oferta/3-pok-mieszkanie-z-potencjalem-inwestycyjnym-ursus-ID4raKE
# Scraped: https://www.otodom.pl/pl/oferta/bezposrednio-do-sprzedazy-2pok-mieszkanie-ID4sak7
# Scraped: https://www.otodom.pl/pl/oferta/ustawne-3-pokoje-tuz-przy-metro-brodno-ID4sq5L
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-vis-a-vis-sinfonia-varsovia-ID4suix
# Scraped: https://www.otodom.pl/pl/oferta/wyjatkowy-apartament-z-duzym-ogrodem-170m-metro-ID4s8GM
# Scraped: https://www.otodom.pl/pl/oferta/piekny-apartament-na-bemowie-ID4qzTA
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-balkon-garaz-miasteczko-wilanow-ID4rF3s
# Scraped: https://www.otodom.pl/pl/oferta/sprzedam-mieszkanie-w-kamienicy-ID4ptpX
# Scraped: https://www.otodom.pl/pl/oferta/piekny-apartament-w-centrum-kamienica-3pok-winda-ID4sui9
# Scraped: https://www.otodom.pl/pl/oferta/3pok-kuchniawindaobok-m1-centrum-ID4saQr
# Scraped: https://www.otodom.pl/pl/oferta/zielonowinda310-wysokoscisprawdz-ID4qUM0
# Scraped: https://www.otodom.pl/pl/oferta/2-pok-na-osiedlu-latawieckameralnie-ID4sltM
# Scraped: https://www.otodom.pl/pl/oferta/taras-zimowy-widok-na-zielen-klimatyzacja-ID4s7zQ
# Page 66
# Scraped: https://www.otodom.pl/pl/oferta/centrum-al-jana-pawla-ii-2-pokoje-39-m2-ID4qKoO
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-ochota-wlochy-na-cesji-nowe-do-odbioru-ID4snKp
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-49m2-balkon-ID4r0If
# Scraped: https://www.otodom.pl/pl/oferta/zielonowinda310-wysokoscisprawdz-ID4qUM0
# Scraped: https://www.otodom.pl/pl/oferta/2-pok-na-osiedlu-latawieckameralnie-ID4sltM
# Scraped: https://www.otodom.pl/pl/oferta/taras-zimowy-widok-na-zielen-klimatyzacja-ID4s7zQ
# Scraped: https://www.otodom.pl/pl/oferta/stary-wilanow-taras-bez-pcc-i-prowizji-ID4piQc
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-od-dewelopera-94m2-z-antresola-metro-ID4mudN
# Scraped: https://www.otodom.pl/pl/oferta/idealne-dla-rodziny-dwupoziomowe-mieszkanie-87-m-2-ID4rpHG
# Scraped: https://www.otodom.pl/pl/oferta/unikalny-apartament-w-przedwojennej-kamienicy-ID4rT3z
# Scraped: https://www.otodom.pl/pl/oferta/kawalerka-balkon-rondo-starzynskiego-ID4sgx9
# Scraped: https://www.otodom.pl/pl/oferta/2-pokojowe-mieszkanie-na-zielonej-ochocie-ID4sbMQ
# Scraped: https://www.otodom.pl/pl/oferta/okazja-nowa-cena-apt-przy-pl-konstytucji-ID4rXyo
# Scraped: https://www.otodom.pl/pl/oferta/atrakcyjne-2-pokojowe-mieszkanie-na-mokotowie-ID4slJo
# Scraped: https://www.otodom.pl/pl/oferta/doskonala-lokata-kapitalu-ID4rP1G
# Scraped: https://www.otodom.pl/pl/oferta/niedaleko-ronda-wiatraczna-nowa-cena-ID4rbQo
# Scraped: https://www.otodom.pl/pl/oferta/widok-na-panorame-warszawy-nowa-cena-ID4rb0o
# Scraped: https://www.otodom.pl/pl/oferta/ostatni-lokal-ID4q2q5
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-praga-poludnie-zielen-cisza-kamienica-ID4suhE
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-2-pokojowe-z-ogrodkiem-ul-poezji-ID4rLjx
# Scraped: https://www.otodom.pl/pl/oferta/3-pok-z-ogrodem-blisko-metra-zielona-okolica-ID4qMiJ
# Scraped: https://www.otodom.pl/pl/oferta/1-2-pok-na-zielonej-woli-metro-9-min-ID4sn9E
# Scraped: https://www.otodom.pl/pl/oferta/1-2-pok-kameralna-inwestycja-metro-10-min-ID4qdsr
# Scraped: https://www.otodom.pl/pl/oferta/super-mieszkanie-200m-do-stacji-m2-lazurowa-ID4o4o9
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-blisko-metro-las-kabacki-ID4ssKp
# Scraped: https://www.otodom.pl/pl/oferta/3-pokoje-piekny-widok-na-panorame-warszawy-ID4srvj
# Scraped: https://www.otodom.pl/pl/oferta/3-pokoje-120-m2-ogrod-wysoki-standard-ID4saLo
# Scraped: https://www.otodom.pl/pl/oferta/sloneczny-apartament-prestizowa-inwestycja-ID4sar9
# Scraped: https://www.otodom.pl/pl/oferta/prestizowa-inwestycja-4-pokoje-taras-dolny-mokotow-ID4saFd
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-duzy-ogrod-miasteczko-wilanow-ID4rPl3
# Scraped: https://www.otodom.pl/pl/oferta/3-pokoje-taras-pozadana-lokalizacja-ID4rPJn
# Scraped: https://www.otodom.pl/pl/oferta/4-pokoje-miasteczko-wilanow-ID4rReU
# Scraped: https://www.otodom.pl/pl/oferta/kawalerka-przedwojenna-kamienica-do-wejscia-ID4rtsL
# Scraped: https://www.otodom.pl/pl/oferta/4-pokoje-ostoja-wilanow-ogrod-ID4rmOn
# Scraped: https://www.otodom.pl/pl/oferta/penthouse-5-pokoi-wilanow-bez-prowizji-ID4qlf3
# Scraped: https://www.otodom.pl/pl/oferta/2-pokoje-przestronne-miasteczko-wilanow-ID4rbNF
# Scraped: https://www.otodom.pl/pl/oferta/wyjatkowa-oferta-kabaty-4-pokoje-ID4qX92
# Scraped: https://www.otodom.pl/pl/oferta/cale-pietro-2-lokale-taras-185m2-blisko-metro-ID4qAcH
# Scraped: https://www.otodom.pl/pl/oferta/mieszkanie-warszawa-srodmiescie-powisle-ID4py8J
# Page 67
# SaveToFile: /content/drive/My Drive/Projects/Predicting Real Estate Prices in Warsaw/raw_otodom_20240916_204608.csv OK.

# %%
df = pd.read_csv(f'/content/drive/My Drive/Projects/Predicting Real Estate Prices in Warsaw/raw_otodom_{timestamp}.csv')

# %% [markdown]
# ### Data cleaning

# %%
def replace_strings(column_data, remove_text, new_value):
    """
    This function replaces a specific substring in a given column value with a new value.

    Arguments:
      column_data (str): The content of a single cell in a column.
      remove_text (str): The substring that should be removed or replaced.
      new_value (str): The value that will replace the specified substring.
    """
    if pd.isna(column_data):  #Check NaN
        return column_data

    # Replace string
    data = column_data.replace(remove_text, new_value)

    return data

def extract_area_from_column(df, column_name, new_column_name):
    """
    Extracts the area (in m²) from the beginning of a text in a specified column and stores it in a new column, while removing the area from the original column.

    Arguments:
        df (DataFrame): The DataFrame containing the data.
        column_name (str): The column to extract the area value from.
        new_column_name (str): The column where the extracted area value will be stored.
    """
    area_regex = r'^(\d+(\.\d+)?)m²'

    df[new_column_name] = df[column_name].apply(lambda x: re.search(area_regex, x).group(1) if isinstance(x, str) and re.search(area_regex, x) else None)

    df[column_name] = df[column_name].apply(lambda x: re.sub(area_regex, '', x).strip() if isinstance(x, str) else x)

    return df


def extract_rooms_from_column(df, column_name, new_column_name):
    """
    Extracts the number of rooms from a specified column and stores it in a new column, while removing the room count from the original column.

    Arguments:
        df (DataFrame): The DataFrame containing the data.
        column_name (str): The column to extract the number of rooms from.
        new_column_name (str): The column where the extracted room count will be stored.
    """
    rooms_regex = r'^(\d+)\s*(pokój|pokoje)'

    df[new_column_name] = df[column_name].apply(lambda x: re.search(rooms_regex, x).group(1) if isinstance(x, str) and re.search(rooms_regex, x) else None)

    df[column_name] = df[column_name].apply(lambda x: re.sub(rooms_regex, '', x).strip() if isinstance(x, str) else x)

    return df

def extract_key_value_pairs(column_data):
    """
    Extracts key-value pairs from a string where the key is followed by a colon and the value comes after.

    Arguments:
        column_data (str): The text containing key-value pairs to extract.
    """
    key_value_regex = r'([A-Z][a-zA-Z\s]*):([^A-Z]*)'

    pairs = []

    if isinstance(column_data, str):
        matches = re.findall(key_value_regex, column_data)
        for match in matches:
            key = match[0].strip()
            value = match[1].strip()
            pairs.append((key, value))

    return pairs

def extract_key_value_columns(df, column_name):
    """
    Extracts key-value pairs from a specified column and creates new columns for each key, with corresponding values.

    Arguments:
        df (DataFrame): The DataFrame containing the data.
        column_name (str): The column from which key-value pairs will be extracted.
    """
    key_value_dict = {}

    for index, row in df.iterrows():
        key_value_pairs = extract_key_value_pairs(row[column_name])

        for key, value in key_value_pairs:
            if key not in key_value_dict:
                key_value_dict[key] = [None] * len(df)
            key_value_dict[key][index] = value

    for key, values in key_value_dict.items():
        df[key] = values

    return df

def extract_location_info(row):
    """
    Analyzes the 'Location' column to extract city, district, voivodeship, and street information.

    Arguments:
        row (Series): A row from the DataFrame containing location data.

    Returns:
        Series: The modified row with new fields for city, district, voivodeship, and street.
    """
    location = row['Location']
    if not isinstance(location, str):
        return row

    city, district, voivodeship, street = None, None, None, None

    parts = location.split(',')

    if "mazowieckie" in location:
        voivodeship = "mazowieckie"

    if "Warszawa" in location:
        city = "Warszawa"

    for part in parts:
        part = part.strip()
        if part in districts:
            district = part
            break

    street_match = re.search(r'(ul\.[^,]*),', location)
    if street_match:
        street = street_match.group(1).strip()

    row['City'] = city
    row['District'] = district
    row['Voivodeship'] = voivodeship
    row['Street'] = street

    return row

# Delete "Mieszkanie na sprzedaż" and "Budynek i materiały" strings
df['Additional information 1'] = df['Additional information 1'].apply(lambda x: replace_strings(x, "Mieszkanie na sprzedaż", ''))
df['Additional information 2'] = df['Additional information 2'].apply(lambda x: replace_strings(x, "Budynek i materiały",''))

# Extract area
df = extract_area_from_column(df, 'Additional information 1', 'Area')

# Extract rooms
df = extract_rooms_from_column(df, 'Additional information 1', 'Rooms')


# Apply function to "Additional information 1" and "Additional information 2" columns
df = extract_key_value_columns(df, 'Additional information 1')
df = extract_key_value_columns(df, 'Additional information 2')

# Delete "Aktualizacja: " and "Dodano: "
df['Update date'] = df['Update date'].apply(lambda x: replace_strings(x, "Aktualizacja: ", ''))
df['Creation date'] = df['Creation date'].apply(lambda x: replace_strings(x, "Dodano: ", ''))

# Dictionary with polish words and
column_name_mapping = {
    'Ogrzewanie': 'Heating',
    'Czynsz': 'Rent',
    'Rynek': 'Market',
    'Informacje dodatkowe': 'Additional Information',
    'Rok budowy': 'Year of construction',
    'Winda': 'Elevator',
    'Rodzaj zabudowy': 'Building type',
    'Zabezpieczenia': 'Security',
    'Media': 'Utilities',
    'Okna': 'Windows',
    'Certyfikat energetyczny': 'Energy certificate'
}

# Rename columns using mapping
df.rename(columns=column_name_mapping, inplace=True)

districts = [
    "Bemowo", "Białołęka", "Bielany", "Mokotów", "Ochota", "Praga-Południe",
    "Praga-Północ", "Rembertów", "Śródmieście", "Targówek", "Ursus", "Ursynów",
    "Wawer", "Wesoła", "Wilanów", "Włochy", "Wola", "Żoliborz"
]

#Apply extract_location_info
df = df.apply(extract_location_info, axis=1)

# Replace strings in Security
df['Security'] = df['Security'].apply(lambda x: replace_strings(x, " / ", ','))


# Save data to .csv file
df.to_csv(f'/content/drive/My Drive/Projects/Predicting Real Estate Prices in Warsaw/clean_otodom_{timestamp}.csv', index=False)
df
# Out:
#                Additional Information  \
# 0    balkon piwnica oddzielna kuchnia
# 1     balkon garaż/miejsce parkingowe
# 2     balkon garaż/miejsce parkingowe
# 3     balkon garaż/miejsce parkingowe
# 4                      balkon piwnica
# ..                                ...
# 447                              None
# 448                              None
# 449                              None
# 450                              None
# 451                              None
#
#                               Additional information 1  \
# 0    Ogrzewanie:miejskiePiętro:9/10Czynsz:750 złSta...
# 1    Ogrzewanie:brak informacjiPiętro:1/3Czynsz:bra...
# 2    Ogrzewanie:miejskiePiętro:3/5Czynsz:brak infor...
# 3    Ogrzewanie:miejskiePiętro:3/6Czynsz:850 złStan...
# 4    Ogrzewanie:miejskiePiętro:1/4Czynsz:490 złStan...
# ..                                                 ...
# 447                                    brak informacji
# 448                                    brak informacji
# 449                                    brak informacji
# 450                                    brak informacji
# 451                                    brak informacji
#
#                               Additional information 2   Area Building type  \
# 0    Rok budowy:1980Winda:takRodzaj zabudowy:blokOk...     48          blok
# 1                                                  NaN  42.73          None
# 2    Winda:takRodzaj zabudowy:blokOkna:plastikoweBe...  76.66          blok
# 3    Rok budowy:2005Winda:takRodzaj zabudowy:blokMa...  75.32          blok
# 4    Winda:nieRodzaj zabudowy:blokOkna:plastikoweCe...   48.5          blok
# ..                                                 ...    ...           ...
# 447                                    brak informacji   None          None
# 448                                    brak informacji   None          None
# 449                                    brak informacji   None          None
# 450                                    brak informacji   None          None
# 451                                    brak informacji   None          None
#
#          City Creation date  \
# 0    Warszawa     8.08.2024
# 1    Warszawa     4.03.2024
# 2    Warszawa     6.08.2024
# 3    Warszawa    24.06.2024
# 4    Warszawa    26.08.2024
# ..        ...           ...
# 447       NaN           NaN
# 448       NaN           NaN
# 449       NaN           NaN
# 450       NaN           NaN
# 451       NaN           NaN
#
#                                                   Desc        District  \
# 0    Do sprzedania bezpośrednio od właściciela 3 po...  Praga-Południe
# 1    2-pokojowe mieszkanie numer 20  na 1. piętrze ...       Białołęka
# 2    LEX NIERUCHOMOŚCI MARTA KOSMOWSKA, TEL.  \nOfe...          Włochy
# 3    Oferuję na sprzedaż przestronne, jasne o funkc...          Bemowo
# 4    Oferta bezpośrednia. Klimatyczne, widne, ciche...         Mokotów
# ..                                                 ...             ...
# 447                                                NaN             NaN
# 448                                                NaN             NaN
# 449                                                NaN             NaN
# 450                                                NaN             NaN
# 451                                                NaN             NaN
#
#     Elevator  ...                                    Security  Source  \
# 0        tak  ...  drzwi,okna antywłamaniowe domofon,wideofon  Otodom
# 1       None  ...                                        None  Otodom
# 2        tak  ...  drzwi,okna antywłamaniowe domofon,wideofon  Otodom
# 3        tak  ...                            domofon,wideofon  Otodom
# 4        nie  ...                            domofon,wideofon  Otodom
# ..       ...  ...                                         ...     ...
# 447     None  ...                                        None  Otodom
# 448     None  ...                                        None  Otodom
# 449     None  ...                                        None  Otodom
# 450     None  ...                                        None  Otodom
# 451     None  ...                                        None  Otodom
#
#                   Street                                              Title  \
# 0                   None  3 pokojowe obok Saska Kępa, Super widok na Cen...
# 1            ul. Duninów   2-pokojowe mieszkanie 42m2 + balkon Bez Prowizji
# 2                   None                     Ochota , 4 pok. 76,66 m, garaż
# 3         ul. Grodkowska       Narożne,3 sypialnie,duży balkon, przestronne
# 4    ul. Konstancińska 7      Klimatyczne 2 pok. wśród zieleni na Mokotowie
# ..                   ...                                                ...
# 447                  NaN             Penthouse/5 pokoi/Wilanów/bez prowizji
# 448                  NaN          2 pokoje/ przestronne/ Miasteczko Wilanów
# 449                  NaN                   wyjątkowa oferta/Kabaty/4 pokoje
# 450                  NaN    całe piętro- 2 lokale/taras 185m2/ blisko metro
# 451                  NaN          Mieszkanie - Warszawa Śródmieście Powiśle
#
#     Update date                                                Url  \
# 0    16.09.2024  https://www.otodom.pl/pl/oferta/3-pokojowe-obo...
# 1    16.09.2024  https://www.otodom.pl/pl/oferta/2-pokojowe-mie...
# 2    16.09.2024  https://www.otodom.pl/pl/oferta/ochota-4-pok-7...
# 3    15.09.2024  https://www.otodom.pl/pl/oferta/narozne-3-sypi...
# 4    15.09.2024  https://www.otodom.pl/pl/oferta/klimatyczne-2-...
# ..          ...                                                ...
# 447         NaN  https://www.otodom.pl/pl/oferta/penthouse-5-po...
# 448         NaN  https://www.otodom.pl/pl/oferta/2-pokoje-przes...
# 449         NaN  https://www.otodom.pl/pl/oferta/wyjatkowa-ofer...
# 450         NaN  https://www.otodom.pl/pl/oferta/cale-pietro-2-...
# 451         NaN  https://www.otodom.pl/pl/oferta/mieszkanie-war...
#
#                               Utilities  Voivodeship     Windows  \
# 0                     telewizja kablowa  mazowieckie  plastikowe
# 1                                  None  mazowieckie        None
# 2            telewizja kablowa internet  mazowieckie  plastikowe
# 3                                  None  mazowieckie  plastikowe
# 4    telewizja kablowa internet telefon  mazowieckie  plastikowe
# ..                                  ...          ...         ...
# 447                                None          NaN        None
# 448                                None          NaN        None
# 449                                None          NaN        None
# 450                                None          NaN        None
# 451                                None          NaN        None
#
#     Year of construction
# 0                   1980
# 1                   None
# 2                   None
# 3                   2005
# 4                   None
# ..                   ...
# 447                 None
# 448                 None
# 449                 None
# 450                 None
# 451                 None
#
# [452 rows x 28 columns]

# %% [markdown]
# ## olx.pl API

# %% [markdown]
# ## Additional data from description using LLM

# %% [markdown]
# ## data on additional places in the area
